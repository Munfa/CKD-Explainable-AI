# %% [markdown]
# # Importing Libraries

# %%
# !pip install fg-data-profiling

# %%
import pandas as pd
import numpy as np
from data_profiling import ProfileReport

# %% [markdown]
# #Dataset: CKD_Dataset

# %%
df = pd.read_excel("/content/CKD_dataset.xlsx")

df.head()
# Out:
#    p_id  age  gender u_clarity   ph   sp_g albumin glucose     sugar  \
# 0     1   28    male  p.yellow  5.0  1.010   trace    nill      nill
# 1     2   43  female    yellow  5.5  1.020   trace    nill  positive
# 2     3   32  female  p.yellow  5.0  1.010    nill    nill      nill
# 3     4   64  female    yellow  5.0  1.015   trace    nill      nill
# 4     5   37    male  p.yellow  5.0  1.010    nill    nill      nill
#
#           kb  ...     blood pus_cells red_cells epi_cells       mt        co  \
# 0  not_trace  ...  negative    normal    normal      nill     none  positive
# 1  not_trace  ...  negative  abnormal  abnormal  positive  present      nill
# 2  not_trace  ...  negative    normal    normal      nill     none      nill
# 3  not_trace  ...  negative  abnormal  abnormal  positive  present  positive
# 4  not_trace  ...  negative    normal    normal      nill     none      nill
#
#      gc bacteria        cc d_status
# 0  seen  notseen  notfound   notckd
# ...

# %%
df.tail()
# Out:
#      p_id  age  gender u_clarity   ph   sp_g albumin   glucose sugar  \
# 375   376   52  female    yellow  5.0  1.025   trace  positive  nill
# 376   377   67  female    yellow  5.0  1.025   trace  positive  nill
# 377   378   41  female    yellow  5.0  1.020    nill      nill  nill
# 378   379   63  female    yellow  6.0  1.020   trace  positive  nill
# 379   380   38  female    yellow  5.5  1.020   trace      nill  nill
#
#             kb  ...     blood pus_cells red_cells epi_cells       mt  \
# 375  not_trace  ...  negative  abnormal    normal  positive  present
# 376  not_trace  ...  negative  abnormal    normal  positive     none
# 377  not_trace  ...  negative    normal    normal      nill  present
# 378  not_trace  ...  negative  abnormal  abnormal  positive  present
# 379  not_trace  ...  negative    normal    normal  positive  present
#
#            co    gc bacteria        cc d_status
# 375      nill  nill  notseen  notfound      ckd
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   p_id       380 non-null    int64
#  1   age        380 non-null    int64
#  2   gender     380 non-null    object
#  3   u_clarity  380 non-null    object
#  4   ph         380 non-null    float64
#  5   sp_g       380 non-null    float64
#  6   albumin    380 non-null    object
#  7   glucose    380 non-null    object
#  8   sugar      380 non-null    object
#  9   kb         380 non-null    object
#  10  bpigment   380 non-null    object
#  11  ur_bi      380 non-null    object
#  12  blood      380 non-null    object
#  13  pus_cells  380 non-null    object
#  14  red_cells  380 non-null    object
#  15  epi_cells  380 non-null    object
#  16  mt         380 non-null    object
#  17  co         380 non-null    object
#  18  gc         380 non-null    object
# ...

# %%
df.describe()
# Out:
#              p_id         age          ph        sp_g
# count  380.000000  380.000000  380.000000  380.000000
# mean   190.500000   44.760526    5.565000    1.015934
# std    109.840794   15.852653    0.561482    0.005262
# min      1.000000   12.000000    5.000000    1.000000
# 25%     95.750000   32.000000    5.000000    1.010000
# 50%    190.500000   44.000000    5.500000    1.020000
# 75%    285.250000   56.000000    6.000000    1.020000
# max    380.000000   91.000000    8.000000    1.050000

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# Length: 380, dtype: bool

# %%
df.shape
# Out:
# (380, 22)

# %%
df.columns.tolist()
# Out:
# ['p_id',
#  'age',
#  'gender',
#  'u_clarity',
#  'ph',
#  'sp_g',
#  'albumin',
#  'glucose',
#  'sugar',
#  'kb',
#  'bpigment',
#  'ur_bi',
#  'blood',
#  'pus_cells',
#  'red_cells',
#  'epi_cells',
#  'mt',
#  'co',
#  'gc',
#  'bacteria',
#  'cc',
#  'd_status']

# %%
df_report = ProfileReport(df, title="Exploratory Data Analysis of CKD Dataset")

# %%
df_report.to_file("ckd_dataset_summary.html")
